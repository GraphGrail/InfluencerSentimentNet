# %%
import spacy
import csv

from cryptoObjectSearcher import CryptoObjectSearcher

# %%
projectNames = 'b21', 'varanida', 'dona', 'hybrid betting', 'allspark', 'lambda', 'tip blockchain', 'miner edge', 'iame identity', 'trilliant', 'alchemy coin', 'ubcoin market', 'gabro', 'iotw', 'lantah', 'primary', 'trueplay', 'eo.trade', 'immvrse', 'curaizon', 'weicrowd', 'pavocoin', 'viva', 'laneaxis', 'chynge', 'pingpaid', 'techrod', 'lexit', 'ubex', 'tutellus', 'accounting blockchain', 'provoco', 'multiven mom', 'smart trip platform', 'ludcoin', 'revenyou', 'aiar', 'tanibox', 'geneos', 'treon', 'augur', 'lisk', 'digix dao', 'waves', 'neo', 'stratis', 'tao network', 'incent', 'blockpay', 'firstblood', 'iconomi', 'lykke', 'synereo', 'singulardtv', 'beyond the void', 'decent', 'golem', 'ark', 'vdice.io', 'komodo', 'golos', 'creativecoin', 'wings', 'tokes', 'chronobank', 'qtum', 'edgeless', 'iex.ec', 'encryptotel', 'gnosis', 'mobilego', 'humaniq', 'lunyr', 'taas', 'blockpool', 'tokencard', 'ecobit', 'boscoin', 'blockchain capital', 'zrcoin', 'aeternity', 'ethbits', 'peerplays', 'aragon', 'monaco', 'storj', 'crypviser', 'quantum rl', 'cryptoping', 'adelphoi', 'veritaseum', 'mysterium', 'exscudo', 'patientory', 'basic attention token', 'wagerr', 'nvo', 'sphre', 'dcorp', 'gigawatt', 'voise', 'bancor', 'fund yourself now', 'minexcoin', 'compcoin', 'sonm', 'status', '21 million', 'beth', 'onegram', 'civic', 'internet of coins', 'populous', 'primalbase', 'adtoken', 'omise go', 'mybit', 'bitquence', 'santiment', 'cofound.it', 'metal', 'insurex', 'dent', 'tezos', 'tenx', 'district0x', 'stox', 'starta', 'cryptoabs', 'suretly', 'hive', 'coinjob', '0x', 'coindash', 'decentraland', 'rivet', 'obsidian', 'corion platform', 'imperium', 'aicoin', 'rasputinonline coin', 'bowhead', 'atb coin', 'monetha', 'benjacoin', 'tron', 'arena', 'snapup', 'filecoin', 'hubii network', 'ahoolee', 'wild crypto', 'aventus', 'daseron', 'bitdice', 'icobox', 'kickico', 'umbrella coin', 'kyber network', 'becksang', 'detectortoken', 'kin', 'reality clash', 'jnet1', 'litra coin', 'axionv', 'moneypotx', 'prover', 'planes cloud', 'lust.agency', 'power ledger', 'domraider', 'bitjob', 'eventchain', 'hedge token', 'paragon coin', 'dls academy', 'ethbet', 'eidoo', 'digi', 'airtoken', 'chainlink', 'mywill platform', 'flyp.me', 'cobinhood', 'sex service', 'bookira', 'blockv', 'chex', 'key token', 'astronaut', 'clearpoll', 'soma', 'swarm fund', 'langpie', 'tokenlab', 'grant hero', 'cryptopay', 'aeron', 'assistive reality', 'bannercoin', 'atlant', 'aldoin', 'dentacoin', 'ethino', 'ripio credit network', 'crypto.tickets', 'utrust', 'starbase', 'qvolta', 'altocar', 'cryptohive', 'blockstack', 'genesis vision', 'crederoom', 'privatix', 'copico', 'micromoney', 'careerxon', 'cash poker pro', 'happiest at work', 'synapse', 'wandx', 'blockbid', 'confideal', 'safe child future', 'multibot', 'zeus', 'bonpay', 'wax', 'storm', 'playkey.io', 'sense', 'vezt ico', 'coppay', 'ccore', 'publica', 'dmarket', 'verifyunion', 'geens', 'jboxcoin', 'dimnd', 'algo.land', 'aml bitcoin', 'worldcore', 'delphi systems', 'aigang network', 'medibloc', 'naga group', 'xred', 'vega ai solutions', 'prosenselive', 'neufund', 'sophiatx', 'investy', 'chainium', 'miniapps.pro', 'foreground', 'novacool', 'connectius', 'rega risk sharing', 'propthereum', 'ethersport', 'indahash', 'debitum network', 'kevin', 'hdac', 'ethereum high', 'binary.com', 'finney', 'remme', 'ins ecosystem', 'prosume energy', 'canya', 'decentralized escrow', 'ethlend', 'bankex', 'spectiv', 'nau', 'dao playmarket 2.0', 'lh-crypto', 'liveshow', 'styras', 'odmcoin', 'freedom streaming', 'familypoints', 'cryptonetix', 'fantasy market', 'loan or lease', 'trade.io', 'cybertrust', 'blockchain traded fund', 'u.cash', 'stars group', 'swissborg', 'lendoit', 'crypterium', 'envion (evn)', 'gatcoin', 'covesting', 'appcoins', 'tzero', 'solareum', 'travelflex coin', 'elastos', 'real estate coupon', 'bitdegree', 'liveedu', 'propify', 'jibrel network', 'polymath', 'storiqa', 'gameflip - flip (flp)', 'vimarket', 'pocketinns', 'kind ads', 'crowdwiz', 'the bee token', 'shipchain', 'shping', 'iungo', 'uservice', 'aidcoin', 'energitoken', 'wepower', 'inspeer', 'sharpe capital', 'escapetoken', 'arcblock', 'fusion', 'scorum', '3d-token', 'redmegawatt', 'skraps', 'dether', 'digit coin', 'cryptoibet', 'bmarkt', 'fuzex', 'matrix', 'krios', 'republic protocol', 'vaultbank', 'colu local network', 'outing', 'bitroad', 'taklimakan network', 'babb', 'biofactorycoin', 'crypto trust network', 'local world forwarders', 'odyssey', 'remechain', 'hoqu', 'paypro', 'streamspace', 'mark.space', 'raison', 'rentberry', 'stockchain global', 'multigames', 'hurify', 'cacaoshares', 'chain id', 'dadi', 'blocklancer', 'tradove', 'volinex', 'lucyd', 'datx', 'apex', 'lympo', 'nucleus.vision', 'credits', 'vionex', 'minerdog', 'napoleonx', 'cryptohawk', 'deex', 'kyc.legal', 'corusblock', 'watertech', 'medicalchain', 'e-chat', 'electrify.asia', 'helbiz coin', 'daneel', 'ip sharing exchange', 'jet8', 'havven', 'serenity', 'phi token', 'telegram', 'dogezer', 'ocean protocol', 'ethic hub', 'safe haven', 'cryptotask', 'scrinium', 'sp8de', 'leadcoin', 'cryptaur', 'refereum', 'travelchain project', 'myoddz.bet', 'prodeum', 'play2live', 'viso', 'dragon inc', 'syncfab', 'denaro', 'aiom', 'capdax', 'valid', 'egold', 'noah coin', 'globitex', 'opporty', 'adhive', 'viewly', 'cappasity', 'origami network', 'crypto n kafe', 'fundfantasy', 'vestopia', 'exenium', 'selfllery', 'gilgamesh', 'booleancoin', 'nami.trade', 'winco', 'joy token', 'wawllet', 'cdg', 'requitix', 'ens.bid', 'wikibits', 'pitch', 'thought', 'crowdholding', 'bitrent', 'beefcoin', 'forty seven bank', 'handelion', 'ab-chain', 'galaxy esolutions', 'skychain', 'clearcoin', 'eroiy', 'fabric token', 'the coffee token', 'true reply', 'paysura', 'nkor', 'hashbux', 'bitto exchange', 'ether legends (elet)', 'amon', 'vestarin', 'thrive', 'r3sec', 'repux', 'bank of hash power', 'renteum', 'bills', 'sandblock', 'vlb', 'signals network', 'gizer', 'md tokens', 'cubaaz', 'on.live', 'rxeal', 'flogmall', 'mosaic', 'viola.ai', 'iolite', 'moxyone', 'rentaway', 'neurochain', 'native video box', 'midex', 'node', 'bitether', 'blockpix', 'hamster marketplace', 'moneytap token', 'giftcoin', 'benebit', 'xyo network', 'ponder', 'bitcar', 'rexpax', 'dehedge', 'kryll.io', 'auctus', 'pokersports', 'smrt', 'lendingblock', 'alax', 'follex', 'otcrit', 'bitnation', 'checqit', 'gluon', 'dapcash', 'astorgame', 'connectjob', 'galaxis', 'corl', 'florafic', 'robotina', 'fox trading', 'cryptelo', 'cartel chain', 'medichain.online', 'thinkcoin', 'wiix', 'etherty', 'ipstock', 'elementh', 'decentralized news network', 'kerberos coin', 'paymon', 'ceek', 'nickelcoin', 'intimate.io', 'eligma', 'patron', 'blocside sports', 'nexusless', 'shivom', 'bitguild', 'lunes platform', 'ambit', 'arcona', 'fic network', 'emarketchain', 'brickblock', 'cargocoin', 'spindle', 'smartrealty', 'worldopoly', 'synthestech', 'worldwifi', 'goldiam', 'dreamteam', 'mira', 'frya', 'windenergymining', 'unibright', 'likecoin', 'crowd machine', 'rentything', 'mass vehicle ledger', 'graphgrail ai', 'smoke', 'bunnytoken', 'mobilebridge', 'coinadvisor', 'transcrypt', 'xsolus', 'datecoin', 'adblurb', 'zuflo.io', 'iryo', 'gochain', 'diw token', 'birdchain', 'jointedu', 'bitrust', 'bitproperty', 'stex exchange', 'cool cousin', 'successlife', 'fcfl', 'virtonomics', 'transcodium', 'gamblica', 'bitminutes', 'kora network', 'eos', 'safinus', 'etheera', 'cultural places', 'stasyq', 'topiacoin', 'moneytoken', 'coinoil', 'white rabbit', 'multiversum', 'gifcoin', 'cryde', 'crystals', 'airchain network', 'cryptoflix', 'binkd', 'bhom', 'bioritmai', 'befund', 'qykbar', 'cryptectum', 'dacc', 'earthmedz', 'deedcoin', 'acorn collective', 'weevocity', 'coin mine australia', 'savage token', 'icst', 'prether', 'adamant messenger', 'well', 'triwer', 'equi', 'lotus core', 'robet', 'global reit', 'globatalent', 'konios', 'all-stocks network', 'realcasino', 'paygine', 'teacher coin', 'coti', 'tripbit', 'winstars', 'd-zone coin', 'verv (vlux)', 'databroker dao', 'essentia', 'crowdif', 'xsearch', 'verasity', 'delphi technologies token.', 'nihilum', 'mandala', 'friend', 'odyfund', 'vernam', 'abacasxchange', 'beat', 'kepler technologies', 'ftec', 'payera', 'luckchemy', 'gana', 'iac autounit', 'recordskeeper', 'typerium', 'yumerium', 'tv-two', 'plentix', 'criptohub', 'valorem foundation', 'coinet', 'iaqua', 'lendsbay', 'avinoc', 'playtness', 'kasko2go', 'trustedcars flex', 'darico', 'coins4favors', 'sportscastr fanchain', 'pr network', 'bounty angels', 'ligercoin', 'starflow', 'datareum', 'streamity', 'botchain', 'codex protocol', 'mydfs', 'mib coin', 'ingot coin', 'metamorph pro', 'denchmusic', 'invest in brokers', 'bidipass', 'ronaldinho soccer coin', 'jullar', 'vite', 'vogov', 'modern finance chain', 'lendchain', 'beaxy exchange', 'mobu', 'bithemoth', 'fysical', 'gny', 'rawg', 'one+1', 'zichain', 'svper', 'sambanx', 'wyzerr', 'arianee', 'black insurance', 'giza device', 'vibeo', '100tokens', 'verifier', 'football bitcademy', 'hussy io', 'aimedis', 'block66', 'Buddy', 'c3c.network', 'cargocoin', 'codex protocol', 'crowd machine', 'cubomania', 'DREAM', 'EkkBaz', 'Emanate', 'EMX', 'Find.Exchange', 'FogCoin', 'Friend', 'Gluon', 'Good Game', 'Hedera Hashgraph', 'idap.io', 'ImmVRse', 'IZX', 'Keep network', 'Konios', 'LAPO Blockchain', 'LeadRex', 'Mattereum', 'Monetizr', 'MustangChain'

# %%
for p in projectNames:
    if "-" in p:
        print(p)
# Out:
# lh-crypto
# gameflip - flip (flp)
# 3d-token
# e-chat
# ab-chain
# all-stocks network
# d-zone coin
# tv-two

# %%
nlp = spacy.load('en')

# %%
d = nlp("100tokens")

# %%
for w in d:
    print(w)
# Out:
# 100tokens

# %%
with open("cryptoProjectNames.csv", "w") as fp:
    writer = csv.writer(fp)
    for p in projectNames:
        writer.writerow([p])

# %%
with open("cryptoProjectNames.csv", "r") as fp:
    reader = csv.reader(fp)
    for row in reader:
        print(row)
# Out:
# ['b21']
# ['varanida']
# ['dona']
# ['hybrid betting']
# ['allspark']
# ['lambda']
# ['tip blockchain']
# ['miner edge']
# ['iame identity']
# ['trilliant']
# ['alchemy coin']
# ['ubcoin market']
# ['gabro']
# ['iotw']
# ['lantah']
# ['primary']
# ['trueplay']
# ['eo.trade']
# ['immvrse']
# ['curaizon']
# ['weicrowd']
# ['pavocoin']
# ['viva']
# ['laneaxis']
# ['chynge']
# ['pingpaid']
# ['techrod']
# ['lexit']
# ['ubex']
# ['tutellus']
# ['accounting blockchain']
# ['provoco']
# ['multiven mom']
# ['smart trip platform']
# ['ludcoin']
# ['revenyou']
# ['aiar']
# ['tanibox']
# ['geneos']
# ['treon']
# ['augur']
# ['lisk']
# ['digix dao']
# ['waves']
# ['neo']
# ['stratis']
# ['tao network']
# ['incent']
# ['blockpay']
# ['firstblood']
# ['iconomi']
# ['lykke']
# ['synereo']
# ['singulardtv']
# ['beyond the void']
# ['decent']
# ['golem']
# ['ark']
# ['vdice.io']
# ['komodo']
# ['golos']
# ['creativecoin']
# ['wings']
# ['tokes']
# ['chronobank']
# ['qtum']
# ['edgeless']
# ...

# %%
s = CryptoObjectSearcher()

# %%
s.search("Hello my name is iotw project I need etp alchemy coin now")
# Out:
# {'projects': [], 'tokens': ['342', '570', '606']}
